# %%
import xarray as xr
from glob import glob

# %%
datadir = '/pscratch/sd/l/linyaoly/ERA5/reanalysis/'
flist = sorted(glob(datadir + 'tcwv_2deg*.nc'))
flist
# Out:
# ['/pscratch/sd/l/linyaoly/ERA5/reanalysis/tcwv_2deg1978.nc',
#  '/pscratch/sd/l/linyaoly/ERA5/reanalysis/tcwv_2deg1979.nc',
#  '/pscratch/sd/l/linyaoly/ERA5/reanalysis/tcwv_2deg1980.nc',
#  '/pscratch/sd/l/linyaoly/ERA5/reanalysis/tcwv_2deg1981.nc',
#  '/pscratch/sd/l/linyaoly/ERA5/reanalysis/tcwv_2deg1982.nc',
#  '/pscratch/sd/l/linyaoly/ERA5/reanalysis/tcwv_2deg1983.nc',
#  '/pscratch/sd/l/linyaoly/ERA5/reanalysis/tcwv_2deg1984.nc',
#  '/pscratch/sd/l/linyaoly/ERA5/reanalysis/tcwv_2deg1985.nc',
#  '/pscratch/sd/l/linyaoly/ERA5/reanalysis/tcwv_2deg1986.nc',
#  '/pscratch/sd/l/linyaoly/ERA5/reanalysis/tcwv_2deg1987.nc',
#  '/pscratch/sd/l/linyaoly/ERA5/reanalysis/tcwv_2deg1988.nc',
#  '/pscratch/sd/l/linyaoly/ERA5/reanalysis/tcwv_2deg1989.nc',
#  '/pscratch/sd/l/linyaoly/ERA5/reanalysis/tcwv_2deg1990.nc',
#  '/pscratch/sd/l/linyaoly/ERA5/reanalysis/tcwv_2deg1991.nc',
#  '/pscratch/sd/l/linyaoly/ERA5/reanalysis/tcwv_2deg1992.nc',
# ...

# %%
ds = xr.open_mfdataset(flist)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 180, latitude: 91, time: 64888)
# Coordinates:
#   * longitude  (longitude) float32 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#   * latitude   (latitude) float32 90.0 88.0 86.0 84.0 ... -86.0 -88.0 -90.0
#   * time       (time) datetime64[ns] 1978-01-01 ... 2022-05-31T18:00:00
# Data variables:
#     tcwv       (time, latitude, longitude) float32 dask.array<chunksize=(1460, 91, 180), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-10-11 20:04:46 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
import numpy as np

# %%
np.sum(ds.tcwv.isnull().values)
# Out:
# 0

# %%
ds=ds.rename({"longitude":"lon","latitude":"lat"})

ds['tcwv'].astype(float)

ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 180, lat: 91, time: 64888)
# Coordinates:
#   * lon      (lon) float32 0.0 2.0 4.0 6.0 8.0 ... 350.0 352.0 354.0 356.0 358.0
#   * lat      (lat) float32 90.0 88.0 86.0 84.0 82.0 ... -84.0 -86.0 -88.0 -90.0
#   * time     (time) datetime64[ns] 1978-01-01 ... 2022-05-31T18:00:00
# Data variables:
#     tcwv     (time, lat, lon) float32 dask.array<chunksize=(1460, 91, 180), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-10-11 20:04:46 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
ds1.to_netcdf(dirn+'ERA5.'+flg+'.6hr.1978to2022.nc')

# %%
a = x.isnull()

# %%
b = x.where(a == True, drop=True)

# %%
b
# Out:
# <xarray.DataArray 'u' (time: 1, latitude: 1, longitude: 1)>
# array([[[nan]]], dtype=float32)
# Coordinates:
#   * latitude   (latitude) float32 40.0
#   * longitude  (longitude) float32 168.0
#   * time       (time) datetime64[ns] 2004-02-07T18:00:00
# Attributes:
#     units:          m s**-1
#     long_name:      U component of wind
#     standard_name:  eastward_wind

# %%
ds.sel(time=b.time, longitude=b.longitude, latitude=b.latitude).u.values
# Out:
# array([[[112.09445]]], dtype=float32)

# %%
ds.to_netcdf(datadir + 'lucas.nc',engine='h5netcdf')
