# %%
import numpy as np 
import xarray as xr 

nmem=300
noutputmem=1
nmemUnet=1
normflg = 1
nvar = 1
flg = str(nvar)+'vari_predasinput_'

BCCo = []
BCCc = []

lead = [1, 5, 10, 13, 15, 20, 25, 30]

for leadmjo in lead:
    datesta = np.datetime64(str(2015)) + np.timedelta64(nmem-1+nmemUnet-1+2*leadmjo,'D')
    dateend = np.datetime64(str(2018)+'-12-31') + np.timedelta64(nmem-2+leadmjo,'D')

    # read residual at t+lead
    fnr = '/global/homes/l/linyaoly/ERA5/script/Unet4MJO/LSTM/output/LSTM_NN_MCDO_UNET_'+flg+'RMMERA5_36yr_lead'+str(leadmjo)+'_norm'+str(normflg)+'_dailyinput_nmem'+str(nmem)+'nout1d.nc'
    dsr = xr.open_dataset(fnr)
    # slice the testing data
    dsr1 = dsr.loc[dict(time=slice(datesta, dateend))]
    resi1 = dsr1['RMM'][:,0].values
    resi2 = dsr1['RMM'][:,1].values 


    # read predicted RMM at t+lead
    fnp = '/global/homes/l/linyaoly/ERA5/reanalysis/'+'predicted_MCDO_UNET_19mapstrop_RMMERA5_36yr_lead'+str(leadmjo)+'_dailyinput_mem1d.nc'
    dsp = xr.open_dataset(fnp)
    dsp['RMM'] = dsp['__xarray_dataarray_variable__']
    dsp = dsp.drop(['__xarray_dataarray_variable__'])
    # slice the testing data
    dsp1 = dsp.loc[dict(time=slice(datesta - np.timedelta64(leadmjo,'D'), dateend - np.timedelta64(leadmjo,'D')))]
    RMMp1 = dsp1['RMM'][:,0].values  # (day)
    RMMp2 = dsp1['RMM'][:,1].values  # (day)


    # read the truth data at t+lead 
    fnt = '/global/homes/l/linyaoly/ERA5/reanalysis/RMM_ERA5_daily.nc'
    dst = xr.open_dataset(fnt)
    # slice the training data
    dst1 = dst.loc[dict(time=slice(datesta, dateend))]
    RMMt1 = dst1['RMM'][:,0].values  # (day)
    RMMt2 = dst1['RMM'][:,1].values  # (day)

    # corrected data
    RMMpc1 = resi1
    RMMpc2 = resi2

    a = sum(RMMp1*RMMt1+RMMp2*RMMt2)
    b = np.sqrt(sum(RMMt1*RMMt1+RMMt2*RMMt2))
    c = np.sqrt(sum(RMMp1*RMMp1+RMMp2*RMMp2))
    BCCo.append(a/b/c) 

    a = sum(RMMpc1*RMMt1+RMMpc2*RMMt2)
    b = np.sqrt(sum(RMMt1*RMMt1+RMMt2*RMMt2))
    c = np.sqrt(sum(RMMpc1*RMMpc1+RMMpc2*RMMpc2))
    BCCc.append(a/b/c) 

import matplotlib.pyplot as plt 

plt.plot(lead, BCCo, 'o-', label='original forecast')
plt.plot(lead, BCCc, 'o-', label='corrected forecast')
plt.plot(lead, 0.5 * np.ones(len(lead)))
plt.legend()

plt.xlabel('lead (days)')
plt.ylabel('BCC')
plt.ylim([0.2,1.1])
# Out:
# (0.2, 1.1)

# %%
dsp1['RMM'][:,0].plot()

# %%
# read the truth data at t+lead 
fnt = '/global/homes/l/linyaoly/ERA5/reanalysis/RMM_ERA5_daily.nc'
dst = xr.open_dataset(fnt)
# slice the training data
RMMt1 = dst['RMM'][:,0].values  # (day)
RMMt2 = dst['RMM'][:,1].values  # (day)

from scipy.signal import correlate
from scipy.signal import correlation_lags

x = correlate(RMMt1[:300], RMMt2[:300])

y = correlation_lags(len(RMMt2[:300]),len(RMMt1[:300]))

plt.plot(y[250:-250], x[250:-250])

# %%
import numpy as np 
import xarray as xr 

nmem=300
noutputmem=1
nmemUnet=1
normflg = 1
nvar = 3
flg = str(nvar)+'vari_predasinput_'

BCCo = []
BCCc = []

lead = [1, 5, 10, 13, 15, 20, 25, 30]

for leadmjo in lead:
    datesta = np.datetime64(str(2015)) + np.timedelta64(nmem-1+nmemUnet-1+2*leadmjo,'D')
    dateend = np.datetime64(str(2018)+'-12-31') + np.timedelta64(nmem-2+leadmjo,'D')

    # read residual at t+lead
    fnr = '/global/homes/l/linyaoly/ERA5/script/Unet4MJO/LSTM/output/LSTM_NN_MCDO_UNET_'+flg+'RMMERA5_36yr_lead'+str(leadmjo)+'_norm'+str(normflg)+'_dailyinput_nmem'+str(nmem)+'nout1d.nc'
    dsr = xr.open_dataset(fnr)
    # slice the testing data
    dsr1 = dsr.loc[dict(time=slice(datesta, dateend))]
    resi1 = dsr1['RMM'][:,0].values
    resi2 = dsr1['RMM'][:,1].values 


    # read predicted RMM at t+lead
    fnp = '/global/homes/l/linyaoly/ERA5/reanalysis/'+'predicted_MCDO_UNET_19mapstrop_RMMERA5_36yr_lead'+str(leadmjo)+'_dailyinput_mem1d.nc'
    dsp = xr.open_dataset(fnp)
    dsp['RMM'] = dsp['__xarray_dataarray_variable__']
    dsp = dsp.drop(['__xarray_dataarray_variable__'])
    # slice the testing data
    dsp1 = dsp.loc[dict(time=slice(datesta - np.timedelta64(leadmjo,'D'), dateend - np.timedelta64(leadmjo,'D')))]
    RMMp1 = dsp1['RMM'][:,0].values  # (day)
    RMMp2 = dsp1['RMM'][:,1].values  # (day)


    # read the truth data at t+lead 
    fnt = '/global/homes/l/linyaoly/ERA5/reanalysis/RMM_ERA5_daily.nc'
    dst = xr.open_dataset(fnt)
    # slice the training data
    dst1 = dst.loc[dict(time=slice(datesta, dateend))]
    RMMt1 = dst1['RMM'][:,0].values  # (day)
    RMMt2 = dst1['RMM'][:,1].values  # (day)

    # corrected data
    RMMpc1 = RMMp1 + resi1
    RMMpc2 = RMMp2 + resi2

    a = sum(RMMp1*RMMt1+RMMp2*RMMt2)
    b = np.sqrt(sum(RMMt1*RMMt1+RMMt2*RMMt2))
    c = np.sqrt(sum(RMMp1*RMMp1+RMMp2*RMMp2))
    BCCo.append(a/b/c) 

    a = sum(RMMpc1*RMMt1+RMMpc2*RMMt2)
    b = np.sqrt(sum(RMMt1*RMMt1+RMMt2*RMMt2))
    c = np.sqrt(sum(RMMpc1*RMMpc1+RMMpc2*RMMpc2))
    BCCc.append(a/b/c) 

import matplotlib.pyplot as plt 

plt.plot(lead, BCCo, 'o-', label='original forecast')
plt.plot(lead, BCCc, 'o-', label='corrected forecast')
plt.plot(lead, 0.5 * np.ones(len(lead)))
plt.legend()

plt.xlabel('lead (days)')
plt.ylabel('BCC')
plt.ylim([0.2,1.1])
# Out:
# (0.2, 1.1)

# %%
dsr1['resi'][:,1].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/eofenv/lib/python3.9/site-packages/xarray/core/dataset.py:1395, in Dataset._construct_dataarray(self, name)
#    1394 try:
# -> 1395     variable = self._variables[name]
#    1396 except KeyError:
#
# KeyError: 'resi'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /global/homes/l/linyaoly/ERA5/script/Unet4MJO/LSTM/test.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bperlmutter-p1.nersc.gov/global/homes/l/linyaoly/ERA5/script/Unet4MJO/LSTM/test.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> dsr1['resi'][:,1].plot()
#
# File ~/.conda/envs/eofenv/lib/python3.9/site-packages/xarray/core/dataset.py:1499, in Dataset.__getitem__(self, key)
#    1496     return self.isel(**cast(Mapping, key))
#    1498 if hashable(key):
# -> 1499     return self._construct_dataarray(key)
#    1500 else:
#    1501     return self._copy_listed(key)
#
# File ~/.conda/envs/eofenv/lib/python3.9/site-packages/xarray/core/dataset.py:1397, in Dataset._construct_dataarray(self, name)
#    1395     variable = self._variables[name]
#    1396 except KeyError:
# -> 1397     _, name, variable = _get_virtual_variable(
#    1398         self._variables, name, self._level_coords, self.dims
#    1399     )
#    1401 needed_dims = set(variable.dims)
#    1403 coords: Dict[Hashable, Variable] = {}
#
# File ~/.conda/envs/eofenv/lib/python3.9/site-packages/xarray/core/dataset.py:170, in _get_virtual_variable(variables, key, level_vars, dim_sizes)
#     168     ref_var = dim_var.to_index_variable().get_level_variable(ref_name)
#     169 else:
# --> 170     ref_var = variables[ref_name]
#     172 if var_name is None:
#     173     virtual_var = ref_var
#
# KeyError: 'resi'
