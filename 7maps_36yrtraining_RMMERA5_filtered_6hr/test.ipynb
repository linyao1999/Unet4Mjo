# %%
import numpy as np
import xarray as xr
import pandas as pd

# %%
datadir = '/pscratch/sd/l/linyaoly/ERA5/reanalysis/'
Fn1 = datadir+'ERA5.u200GfltG.6hr.1979to2022.nc'
Fn2 = datadir+'ERA5.u850GfltG.6hr.1979to2022.nc'
Fn3 = datadir+'ERA5.olrGfltG.6hr.1979to2022.nc'
Fn4 = [datadir+'tcwv_2deg2015.nc', datadir+'tcwv_2deg2016.nc']
Fn5 = [datadir+'v200_2deg2015.nc', datadir+'v200_2deg2016.nc']
Fn6 = [datadir+'T200_2deg2015.nc', datadir+'T200_2deg2016.nc']
Fn7 = datadir+'ERA5.sstGfltGmask0.6hr.1979to2022.nc'
Fn = [Fn1,Fn2,Fn3,Fn4,Fn5,Fn6,Fn7]
Fn[3]
# Out:
# ['/pscratch/sd/l/linyaoly/ERA5/reanalysis/tcwv_2deg2015.nc',
#  '/pscratch/sd/l/linyaoly/ERA5/reanalysis/tcwv_2deg2016.nc']

# %%
datadir = '/pscratch/sd/l/linyaoly/ERA5/reanalysis/'
Fn6 = [datadir+'T200_2deg2015.nc', datadir+'T200_2deg2016.nc']
FF6 = xr.open_mfdataset(Fn6) # T200
FF6 = FF6.sel(time=slice(str(2015)+'-01-01', str(2016)+'-01-31'))
FF6
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 180, latitude: 91, time: 1584)
# Coordinates:
#   * longitude  (longitude) float32 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#   * latitude   (latitude) float32 90.0 88.0 86.0 84.0 ... -86.0 -88.0 -90.0
#   * time       (time) datetime64[ns] 2015-01-01 ... 2016-01-31T18:00:00
# Data variables:
#     t          (time, latitude, longitude) float32 dask.array<chunksize=(1460, 91, 180), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-08-23 23:12:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
x = np.arange(2)
print(x)
print(x[-1])
# Out:
# [0 1]
# 1

# %%
datadir = '/pscratch/sd/l/linyaoly/ERA5/reanalysis/'
Fn1 = datadir+'ERA5.u200GfltG.6hr.1979to2022.nc'
Fn2 = datadir+'ERA5.u850GfltG.6hr.1979to2022.nc'
Fn3 = datadir+'ERA5.olrGfltG.6hr.1979to2022.nc'
Fn7 = datadir+'ERA5.sstGfltGmask0.6hr.1979to2022.nc'
Fn = [Fn1,Fn2,Fn3,Fn7]
varn = ['u200','u850','olr','sst']
for i in np.arange(4):
    x = xr.open_dataset(Fn[i])[varn[i]]
    print(np.sum(np.isnan(x.values)))
# Out:
# 0
# 0
# 0
# 0

# %%
datadir = '/pscratch/sd/l/linyaoly/ERA5/reanalysis/'
Fn1 = datadir+'ERA5.u200.day.1978to2022.nc'
Fn2 = datadir+'ERA5.u850.day.1978to2022.nc'
Fn3 = datadir+'ERA5.olr.day.1978to2022.nc'
Fn4 = datadir+'ERA5.tcwv.day.1978to2022.nc'
Fn5 = datadir+'ERA5.v200.day.1978to2022.nc'
Fn6 = datadir+'ERA5.T200.day.1978to2022.nc'
Fn7 = datadir+'ERA5.sst.day.1978to2022.nc'
Fn = [Fn1,Fn2,Fn3,Fn4,Fn5,Fn6,Fn7]
varn = ['u200','u850','olr','tcwv','v200','T200','sst']
for i in np.arange(7):
    x = xr.open_dataset(Fn[i])[varn[i]]
    print(np.sum(np.isnan(x.values)))
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 90113210

# %%
datadir = '/pscratch/sd/l/linyaoly/ERA5/reanalysis/'
Fn1 = datadir+'ERA5.u200.6hr.1978to2022.nc'
Fn2 = datadir+'ERA5.u850.6hr.1978to2022.nc'
Fn3 = datadir+'ERA5.olr.6hr.1978to2022.nc'
Fn4 = datadir+'ERA5.tcwv.6hr.1978to2022.nc'
Fn5 = datadir+'ERA5.v200.6hr.1978to2022.nc'
Fn6 = datadir+'ERA5.T200.6hr.1978to2022.nc'
Fn = [Fn1,Fn2,Fn3,Fn4,Fn5,Fn6,Fn7]
varn = ['u200','u850','olr','tcwv','v200','T200']
for i in np.arange(6):
    x = xr.open_dataset(Fn[i])[varn[i]]
    print(np.sum(np.isnan(x.values)))
# Out:
# 1
# 0
# 0
# 17
# 1
# 2
# 360452856

# %%
from datetime import date
d0 = date(1978, 1, 1)
d1 = date(2022, 5, 31)
delta = d1 - d0
print('The number of days between the given range of dates is :')
print(delta.days)
# Out:
# The number of days between the given range of dates is :
# 16221

# %%
Fn4 = datadir+'ERA5.tcwv.6hr.1978to2022.nc'
ds = xr.open_dataset(Fn4)
x = ds['tcwv']
print(np.sum(np.isnan(x.values)))
x = x.sel(time=slice('2015-01-01','2015-12-31'))
x
# Out:
# 17
# <xarray.DataArray 'tcwv' (time: 1460, lat: 91, lon: 180)>
# array([[[2.321499, 2.321499, ..., 2.321499, 2.321499],
#         [2.675743, 2.730534, ..., 2.562332, 2.61203 ],
#         ...,
#         [0.833168, 0.829346, ..., 0.833168, 0.831894],
#         [0.786022, 0.786022, ..., 0.786022, 0.786022]],
#
#        [[2.231026, 2.231026, ..., 2.231026, 2.231026],
#         [3.61232 , 3.584286, ..., 3.611046, 3.608498],
#         ...,
#         [0.828072, 0.824249, ..., 0.83062 , 0.83062 ],
#         [0.894333, 0.894333, ..., 0.894333, 0.894333]],
#
#        ...,
#
#        [[1.486862, 1.486862, ..., 1.486862, 1.486862],
#         [2.016953, 2.05518 , ..., 1.955788, 1.978725],
#         ...,
#         [0.696823, 0.696823, ..., 0.68663 , 0.693001],
#         [0.577042, 0.577042, ..., 0.577042, 0.577042]],
#
#        [[2.501167, 2.501167, ..., 2.501167, 2.501167],
#         [5.358047, 5.384808, ..., 5.235722, 5.308353],
#         ...,
# ...

# %%
y = x.sel(lat=-80)
z = np.asarray(y)
np.argwhere(np.isnan(z))

y[1048,   34]
# Out:
# <xarray.DataArray 'tcwv' ()>
# array(nan, dtype=float32)
# Coordinates:
#     lon      float32 68.0
#     lat      float32 -80.0
#     time     datetime64[ns] 2015-09-20
# Attributes:
#     units:          kg m**-2
#     long_name:      Total column vertically-integrated water vapour
#     standard_name:  lwe_thickness_of_atmosphere_mass_content_of_water_vapor

# %%
# check why 6hr data has nan
import numpy as np
import xarray as xr
import pandas as pd

dirn = '/pscratch/sd/l/linyaoly/ERA5/reanalysis/'

flg = 'tcwv'
varn = 'tcwv'
ds1 = xr.open_mfdataset(dirn+flg+'_2deg*.nc',combine='by_coords')

ds1=ds1.rename({varn:flg,"longitude":"lon","latitude":"lat"})
ds1[flg].astype(float)
# ds1['time'] = pd.to_datetime(ds1.time)
x = ds1[flg]
print(np.sum(np.isnan(x.values)))
# Out:
# 0

# %%
ds1
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 180, lat: 91, time: 64888)
# Coordinates:
#   * lon      (lon) float32 0.0 2.0 4.0 6.0 8.0 ... 350.0 352.0 354.0 356.0 358.0
#   * lat      (lat) float32 90.0 88.0 86.0 84.0 82.0 ... -84.0 -86.0 -88.0 -90.0
#   * time     (time) datetime64[ns] 1978-01-01 ... 2022-05-31T18:00:00
# Data variables:
#     tcwv     (time, lat, lon) float32 dask.array<chunksize=(1460, 91, 180), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-10-11 20:04:46 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
datadir = '/pscratch/sd/l/linyaoly/ERA5/reanalysis/'
Fn1 = datadir+'ERA5.sstGfltGmask0.day.1979to2022.nc'
ds = xr.open_dataset(Fn1)
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 15857, lat: 91, lon: 180)
# Coordinates:
#   * time     (time) datetime64[ns] 1979-01-01 1979-01-02 ... 2022-05-31
#   * lon      (lon) float32 0.0 2.0 4.0 6.0 8.0 ... 350.0 352.0 354.0 356.0 358.0
#   * lat      (lat) float32 90.0 88.0 86.0 84.0 82.0 ... -84.0 -86.0 -88.0 -90.0
# Data variables:
#     sst      (time, lat, lon) float32 ...

# %%
Fnmjo = '/global/homes/l/linyaoly/ERA5/reanalysis/RMMERA5only/ERA5_RMM_ERA5only.csv'
ds = pd.read_csv(Fnmjo,header=0)

# %%
ds
# Out:
#            RMM1      RMM2        Date
# 0      0.453544  1.590674  1979-01-01
# 1      0.326734  1.887981  1979-01-02
# 2      0.197514  2.293299  1979-01-03
# 3      0.127328  2.263385  1979-01-04
# 4     -0.017271  2.145125  1979-01-05
# ...         ...       ...         ...
# 15852  0.929094  0.715677  2022-05-27
# 15853  0.926939  1.161200  2022-05-28
# 15854  0.873296  1.594230  2022-05-29
# 15855  0.472122  1.784495  2022-05-30
# 15856  0.023212  1.647482  2022-05-31
#
# [15857 rows x 3 columns]

# %%
ds.set_index('Date')
# Out:
#                 RMM1      RMM2
# Date
# 1979-01-01  0.453544  1.590674
# 1979-01-02  0.326734  1.887981
# 1979-01-03  0.197514  2.293299
# 1979-01-04  0.127328  2.263385
# 1979-01-05 -0.017271  2.145125
# ...              ...       ...
# 2022-05-27  0.929094  0.715677
# 2022-05-28  0.926939  1.161200
# 2022-05-29  0.873296  1.594230
# 2022-05-30  0.472122  1.784495
# 2022-05-31  0.023212  1.647482
#
# [15857 rows x 2 columns]

# %%
ds.loc['1979-01-02':'1979-01-03']
# Out:
# Empty DataFrame
# Columns: [RMM1, RMM2, Date]
# Index: []

# %%
xr.open_dataset('/global/homes/l/linyaoly/ERA5/reanalysis/test.nc')
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 15857, mode: 2)
# Coordinates:
#   * time     (time) datetime64[ns] 1979-01-01 1979-01-02 ... 2022-05-31
#   * mode     (mode) int64 0 1
# Data variables:
#     RMM      (time, mode) float32 ...
